# %% [markdown]
# # 1) Study of Embeddings for JD - Resume Matching (Code Explanation)
#
# * *Author - Jithin J Kumar*
# * *Date - 25-01-2019*
# * *Project - JD-Resume Matching Algorithm*
# * *Project Members - Rashmi, Jagadish, Jithin*
#
# ## ReadMe Note
#
# Word Embeddings are an important concept in Natural language processing task. Choosing the correct embedding patterns is supposed to improve the efficeny of the model. Hence in this notebook We have explored 2 of the most common Word embeddings currently in use Word2vec and FastText.
#
# **Library Dependencies**
# * Gensim Version :  3.6.0
#
# **Data Dependencies**
# * outfile - tokenized data in the form of pickle file for preparing model

# %% [markdown]
# #### 1) Importing necessary Libraries

# %%
import numpy as np
import pickle
import gensim
from gensim.models import FastText
import warnings
warnings.filterwarnings("ignore")

print("Gensim Version : ",gensim.__version__)
# Out:
# Gensim Version :  3.6.0

# %% [markdown]
# #### 2) Loading data into memory from pickle file

# %%
with open ('outfile', 'rb') as fp:
    data = pickle.load(fp)

# %%
# data looks like this...
data
# Out:
# [['RESUME', 'Y.Sivaram', '.'],
#  ['Email',
#   ':',
#   'ysivaram.developer',
#   '@',
#   'gmail.com',
#   'VBA',
#   'Developer',
#   '&',
#   'Reporting',
#   'Analyst',
#   '.'],
#  ['Mobile', 'No', ':', '+91-', '9742915208', 'Excel', 'Expert', '.'],
#  ['Career',
#   'objective',
#   ':',
#   'To',
#   'secure',
#   'a',
#   'challenging',
#   'position',
#   'where',
#   'I',
#   'can',
#   'effectively',
#   'contribute',
#   'my',
#   'skills',
#   'as',
#   'Software',
#   'Professional',
#   'possessing',
#   'competent',
#   'Technical',
#   'skills',
#   '.'],
#  ['PROFESSIONAL',
#   'SUMMARY',
#   ':',
#   'Having',
#   '4',
#   'Years',
#   'of',
#   'professional',
#   'IT',
#   'experience',
#   'in',
#   'Visual',
#   'Basic',
#   'for',
#   'Applications',
#   'such',
#   'as',
#   'Excel',
#   'Advanced',
#   'Excel',
#   'VBA',
#   'Macros',
#   'and',
#   'MIS',
#   'Analyst',
#   '.'],
#  ['Customized',
#   'and',
#   'developed',
#   'reusable',
#   'objects',
#   'and',
#   'reports',
#   'highlighting',
#   'process',
#   'status',
#   'for',
#   'each',
#   'record',
#   '.'],
#  ['Generated',
#   'Email',
#   'notifications',
#   'and',
#   'custom',
#   'exception',
#   'handling',
#   '.'],
#  ['Strong',
#   'knowledge',
#   'on',
#   'Excel',
#   'Charts',
#   'Pivots',
#   'Slicers',
#   'Excel',
#   'formulae',
#   'Dashboard',
#   'views',
#   'Index',
#   'Match',
#   'VLOOKUP',
#   '&',
#   'Hookup',
#   'Offset',
#   'named',
#   'ranges',
#   'data',
#   'sorting',
#   'and',
#   'filtering',
#   '.'],
#  ['Having',
#   'proficiency',
#   'knowledge',
#   'with',
#   'Build',
#   'Scripts',
#   'VBA',
#   'macros',
#   '.'],
#  ['Preparing',
#   'excellent',
#   'documentation',
#   'on',
#   'business',
#   'requirements',
#   '.'],
#  ['Developing',
#   'and',
#   'delivering',
#   'MIS',
#   'report',
#   'using',
#   'Excel',
#   'Macro',
#   '’',
#   's',
#   'for',
#   'monthly',
#   'weekly',
#   'and',
#   'Daily',
#   'reports',
#   'to',
#   'Management',
#   '.'],
#  ['Ability',
#   'to',
#   'take',
#   'an',
#   'existing',
#   'database',
#   'structure',
#   '(',
#   'including',
#   'tables',
#   'queries',
#   'forms',
#   'reports',
#   'etc',
#   '.',
#   ')'],
#  ['and', 'optimize', 'it', 'and', 'make', 'it', 'more', 'user-friendly', '.'],
#  ['Experienced',
#   'in',
#   'working',
#   'with',
#   'Pivot',
#   'Tables',
#   'Graphs',
#   'and',
#   'Reports',
#   '.'],
#  ['Having', 'good', 'work', 'experience', 'on', 'User', 'Forms', '.'],
#  ['Having',
#   'strong',
#   'experience',
#   'in',
#   'Arrays',
#   'Functions',
#   'Macro',
#   'programming',
#   'in',
#   'VBA',
#   '.'],
#  ['Have',
#   'work',
#   'experience',
#   'on',
#   'Designing',
#   'on',
#   'New',
#   'Dashboards',
#   'and',
#   'Changes',
#   'in',
#   'Existing',
#   'Dashboards',
#   '.'],
#  ['Developed',
#   'report',
#   'specifications',
#   'based',
#   'on',
#   'user',
#   'requirements',
#   '.'],
#  ['EDUCATIONAL',
#   'QUALIFICATIONS',
#   ':',
#   'B.Tech',
#   '(',
#   'EEE',
#   ')',
#   'from',
#   'JNTU',
#   'Kakinada',
#   'completed',
#   'in',
#   'the',
#   'year',
#   'of',
#   '2011',
#   '.'],
#  ['Employment',
#   'Summary',
#   ':',
#   'Working',
#   'with',
#   'Business',
#   'Intelli',
#   'solutions',
#   'Inc.',
#   'as',
#   'a',
#   'VBA',
#   'Developer',
#   'from',
#   '2014',
#   'March',
#   'to',
#   'till',
#   'date',
#   '.'],
#  ['Project1',
#   ':',
#   'Client',
#   ':',
#   'Tenet',
#   'Healthcare',
#   'Corporation',
#   'TEAM',
#   'SIZE',
#   ':',
#   'Four',
#   'Designation',
#   ':',
#   'VBA',
#   'Developer',
#   'Project',
#   'Description',
#   ':',
#   'HMS',
#   'is',
#   'a',
#   'total',
#   'Health',
#   'Care',
#   'Management',
#   'System',
#   'by',
#   'Tenet',
#   'Healthcare',
#   'Corporation',
#   'in',
#   'U.S',
#   'which',
#   'manages',
#   'the',
#   'total',
#   'Patient',
#   'Administration',
#   'System',
#   'maintained',
#   'in',
#   'three',
#   'different',
#   'modules',
#   ':',
#   'Patient',
#   'Information',
#   'Accounts',
#   'Information',
#   'and',
#   'Monitoring',
#   '.'],
#  ['The',
#   'Patient',
#   'Information',
#   'module',
#   'contains',
#   'the',
#   'patient',
#   'details',
#   'up',
#   'to',
#   '‘',
#   'date',
#   'health',
#   'information',
#   '.'],
#  ['In',
#   'the',
#   'Accounts',
#   'Information',
#   'module',
#   'day-to-day',
#   'bill',
#   'settlements',
#   'are',
#   'entered',
#   'in',
#   'to',
#   'the',
#   'Online',
#   'System',
#   '.'],
#  ['In',
#   'Monitoring',
#   'it',
#   'monitors',
#   'from',
#   'day',
#   'one',
#   'to',
#   'discharged',
#   'date',
#   'of',
#   'the',
#   'patient',
#   'and',
#   'Case',
#   'Sheet',
#   'is',
#   'maintained',
#   'which',
#   'is',
#   'confidential',
#   '.'],
#  ['Roles',
#   'and',
#   'Responsibilities',
#   ':',
#   'Understanding',
#   'and',
#   'analyzing',
#   'the',
#   'business',
#   'requirements',
#   '.'],
#  ['Creating',
#   'New',
#   'Templates',
#   'and',
#   'update',
#   'the',
#   'Templates',
#   'based',
#   'on',
#   'client',
#   'requirements',
#   '.'],
#  ['Receiving',
#   'and',
#   'downloading',
#   'data',
#   'from',
#   'different',
#   'sources',
#   '(',
#   'SQL',
#   'Server',
#   'Oracle',
#   ')',
#   'Cleaning',
#   'and',
#   'Formatting',
#   'data',
#   'using',
#   'by',
#   'EXCEL',
#   '.'],
#  ['Removing', 'duplicate', 'records', 'from', 'Data', '.'],
#  ['Handling',
#   'multiple',
#   'reports',
#   'working',
#   'with',
#   'formulae',
#   'pivot',
#   'tables',
#   '&',
#   'pivot',
#   'charts',
#   'and',
#   'various',
#   'other',
#   'excel',
#   'sheet',
#   'components',
#   'for',
#   'accurate',
#   'data',
#   '.'],
#  ['Updating',
#   'Data',
#   'and',
#   'MIS',
#   'Dashboard',
#   'on',
#   'daily',
#   'and',
#   'weekly',
#   'basis',
#   '.'],
#  ['Create',
#   'VBA',
#   'programs',
#   'to',
#   'automatically',
#   'update',
#   'Excel',
#   'workbooks',
#   '.'],
#  ['Expertise',
#   'in',
#   'MS',
#   'Excel',
#   '(',
#   'Hlookup',
#   'VLookup',
#   ')',
#   'look',
#   'up',
#   'Pivot',
#   'Table',
#   '&',
#   'PivotTable',
#   'Chart',
#   'Charts',
#   'Macro',
#   'Forms',
#   'data',
#   'validation',
#   '&',
#   'Scenarios',
#   ')',
#   '.'],
#  ['Completely', 'comfortable', 'with', 'the', 'VBA', 'IDE', '.'],
#  ['Detailed',
#   'knowledge',
#   'of',
#   'VBA',
#   'to',
#   'be',
#   'able',
#   'to',
#   'write',
#   'modules',
#   'from',
#   'scratch',
#   'including',
#   'ability',
#   'to',
#   'make',
#   'forms',
#   'objects',
#   'and',
#   'worksheets',
#   'and',
#   'all',
#   'powered',
#   'by',
#   'macros',
#   '.'],
#  ['Understands',
#   'events',
#   'classes',
#   'and',
#   'properties',
#   'and',
#   'able',
#   'to',
#   'use',
#   'all',
#   'control',
#   'structures',
#   '.'],
#  ['Automating',
#   'tasks',
#   'approved',
#   'by',
#   'the',
#   'Management',
#   'by',
#   'developing',
#   'VBA-Code',
#   '.'],
#  ['Testing',
#   'whether',
#   'the',
#   'Code',
#   'is',
#   'working',
#   'properly',
#   'and',
#   'debugging',
#   'the',
#   'issues',
#   '.'],
#  ['Project2',
#   ':',
#   'Title',
#   ':',
#   'GSK',
#   'TEAM',
#   'SIZE',
#   ':',
#   'Six',
#   'Designation',
#   ':',
#   'VBA',
#   'Developer',
#   '.'],
#  ['Project',
#   'description',
#   ':',
#   'Single',
#   'Point',
#   'of',
#   'contact',
#   'for',
#   'development',
#   'testing',
#   'and',
#   'design',
#   'of',
#   'custom',
#   'reporting',
#   'solutions',
#   'for',
#   'GSK',
#   '’',
#   's',
#   'branded',
#   'product',
#   'Market',
#   'new',
#   'prescription',
#   '&',
#   'revised',
#   'prescriptions',
#   'for',
#   'USA',
#   '.'],
#  ['Worked',
#   'closely',
#   'with',
#   'GSK',
#   '’',
#   's',
#   'regional',
#   'heads',
#   'to',
#   're-engineer',
#   'reporting',
#   'solutions',
#   'on',
#   'sales',
#   'of',
#   'branded',
#   'drugs',
#   'on',
#   'therapy',
#   'portfolio',
#   'Created',
#   'business',
#   'flows',
#   '/use',
#   'case',
#   'scenarios',
#   'for',
#   'ongoing',
#   'development',
#   'activities',
#   'Prepared',
#   'functional',
#   '&',
#   'technical',
#   'documentation',
#   'Understanding',
#   'the',
#   'existing',
#   'business',
#   'models',
#   'for',
#   'customers',
#   'and',
#   'provide',
#   'effective',
#   'solutions',
#   'Roles',
#   'and',
#   'Responsibilities',
#   ':',
#   'As',
#   'a',
#   'VBA',
#   'developer',
#   'the',
#   'role',
#   'was',
#   'to',
#   'develop',
#   'and',
#   'Single',
#   'Point',
#   'of',
#   'contact',
#   'for',
#   'development',
#   'testing',
#   'and',
#   'design',
#   'of',
#   'custom',
#   'reporting',
#   'solutions',
#   'for',
#   'GSK',
#   '’',
#   's',
#   'branded',
#   'product',
#   'Market',
#   'new',
#   'prescription',
#   '&',
#   'revised',
#   'prescriptions',
#   'for',
#   'USA',
#   '.'],
#  ['Using', 'Excel/VBA', 'and', 'with', 'SQL', 'server', 'as', 'database', '.'],
#  ['Requirement', 'Gathering', 'Process', 'and', 'Documentation', '.'],
#  ['And',
#   'assisting',
#   'my',
#   'seniors',
#   'on',
#   'various',
#   'activities',
#   'like',
#   'looking',
#   'after',
#   'connectivity',
#   'issues',
#   'and',
#   'data',
#   'analysis/inspection',
#   'etc',
#   '.'],
#  ['Extensively',
#   'use',
#   'Excel',
#   'functions',
#   'in',
#   'development',
#   'focusing',
#   'on',
#   'read/write',
#   'integration',
#   'to',
#   'databases',
#   '.'],
#  ['Proven',
#   'background',
#   'translating',
#   'cell',
#   'formulas',
#   'in',
#   'Excel',
#   'into',
#   'VBA',
#   'code',
#   'and',
#   'using',
#   'Excel-based',
#   'VBA',
#   'to',
#   'design',
#   'analyze',
#   'and',
#   'deploy',
#   'programs',
#   '.'],
#  ['Create',
#   'VBA',
#   'programs',
#   'to',
#   'automatically',
#   'update',
#   'Excel',
#   'workbooks',
#   '.'],
#  ['Expertise',
#   'in',
#   'MS',
#   'Excel',
#   '(',
#   'Hlookup',
#   'VLookup',
#   ')',
#   'look',
#   'up',
#   'Pivot',
#   'Table',
#   '&',
#   'PivotTable',
#   'Chart',
#   'Charts',
#   'Macro',
#   'Forms',
#   'data',
#   'validation',
#   '&',
#   'Scenarios',
#   ')',
#   '.'],
#  ['PROFILE',
#   'SUMMARY',
#   'MBA',
#   'in',
#   'Supply',
#   'chain',
#   'Management',
#   'from',
#   'NITIE',
#   '2009-11',
#   'SCM',
#   'professional',
#   'with',
#   'cross',
#   'functional',
#   'experience',
#   'around',
#   '9',
#   'years',
#   'Worked',
#   'and',
#   'trained',
#   'people',
#   'in',
#   'SAP',
#   'IBP',
#   '–',
#   'S',
#   '&',
#   'OP',
#   '/Demand/',
#   'Inventory',
#   'Experience',
#   'in',
#   'all',
#   'aspects',
#   'of',
#   'Demand',
#   'Planning',
#   'Module',
#   'in',
#   'SAP',
#   'SCM',
#   'APO',
#   'and',
#   'aspects',
#   'of',
#   'SNP',
#   'module',
#   '(',
#   'specific',
#   'to',
#   'business',
#   'process',
#   'of',
#   'the',
#   'company',
#   'and',
#   'setting',
#   'up',
#   'Heuristics',
#   '&',
#   'CTM',
#   'profiles',
#   ')',
#   '.'],
#  ['GATP',
#   '(',
#   'multilevel',
#   'ATP',
#   'checks',
#   'Rule',
#   'based',
#   'ATP',
#   'product',
#   'allocation',
#   'Back',
#   'order',
#   'processing',
#   ')',
#   'Has',
#   'experience',
#   'with',
#   'mapping',
#   'of',
#   'the',
#   'Business',
#   'processes',
#   'Gap',
#   'Analysis',
#   'preparing',
#   'script',
#   'test',
#   'for',
#   'Prototype',
#   'Integration',
#   'testing',
#   'Program',
#   'specifications',
#   'for',
#   'customer',
#   'specific',
#   'enhancement',
#   'and',
#   'ABAP',
#   'Worked',
#   'with',
#   'Integration',
#   'of',
#   'the',
#   'R/3',
#   'and',
#   'the',
#   'APO',
#   'systems',
#   'using',
#   'core',
#   'interface',
#   '(',
#   'CIF',
#   ')',
#   'Expertise',
#   'in',
#   'Configuration',
#   'Product',
#   'support',
#   'Testing',
#   'User',
#   'training',
#   'and',
#   'knowledge',
#   'transfer',
#   'Proven',
#   'ability',
#   'to',
#   'communicate',
#   'and',
#   'maintain',
#   'effective',
#   'relationships',
#   'with',
#   'business',
#   'partners',
#   'internal',
#   'and',
#   'global',
#   'development',
#   'teams',
#   'and',
#   'external',
#   'vendors',
#   '.'],
#  ['Provides',
#   'sound',
#   'and',
#   'robust',
#   'analysis',
#   'to',
#   'optimisation',
#   'and',
#   'process',
#   'standardisation',
#   '.'],
#  ['Integrates',
#   'findings',
#   'well',
#   'with',
#   'other',
#   'business',
#   'issues',
#   'whilst',
#   'adhering',
#   'to',
#   'process',
#   'compliance',
#   'Highly',
#   'motivated',
#   'person',
#   'with',
#   'strong',
#   'management',
#   'administration',
#   'problem',
#   'solving',
#   'and',
#   'decision-making',
#   '.'],
#  ['Also',
#   'self-starter',
#   'with',
#   'good',
#   'academic',
#   'record',
#   'and',
#   'a',
#   'good',
#   'team',
#   'player',
#   '.'],
#  ['Good',
#   'command',
#   'in',
#   'using',
#   'Microsoft',
#   'office',
#   'tools',
#   'including',
#   'excel',
#   'skills',
#   'Power',
#   'point',
#   'presentations',
#   'and',
#   'use',
#   'of',
#   'Microsoft',
#   'project',
#   'management',
#   '.'],
#  ['Work',
#   'Experience',
#   'HCL',
#   '(',
#   'Aug',
#   '’',
#   '16-',
#   'Nov',
#   '’',
#   '17',
#   ')',
#   '.'],
#  ['Role',
#   ':',
#   'SAP',
#   'Consultant',
#   'Project',
#   'Details',
#   ':',
#   '-',
#   'GSK-Leading',
#   'Pharmaceutical/consumer',
#   'products',
#   'Company',
#   'Worked',
#   'as',
#   'SAP',
#   'consultant',
#   'for',
#   'GSK',
#   'SAP',
#   'roll-out',
#   'for',
#   'India',
#   'Bangladesh',
#   '&',
#   'Sri',
#   'Lanka',
#   'for',
#   'consumer',
#   '(',
#   'CX',
#   ')',
#   'and',
#   'pharmaceutical',
#   '(',
#   'RX',
#   ')',
#   'domain',
#   '(',
#   'SNP/',
#   'GATP',
#   ')',
#   'Understanding',
#   'the',
#   'complete',
#   'business',
#   'in',
#   'different',
#   'markets',
#   'and',
#   'implementing',
#   'the',
#   'same',
#   'in',
#   'SAP',
#   'for',
#   'Heuristics',
#   'and',
#   'GATP',
#   'Closely',
#   'worked',
#   'with',
#   'business',
#   'in',
#   'each',
#   'phases',
#   'of',
#   'requirement',
#   'gathering',
#   'for',
#   'different',
#   'markets',
#   'as',
#   'per',
#   'their',
#   'trade',
#   'routes',
#   'and',
#   'complexities',
#   'of',
#   'business',
#   'Adhered',
#   'strictly',
#   'to',
#   'GSK',
#   'template',
#   'and',
#   'methodologies',
#   'for',
#   'each',
#   'step',
#   'in',
#   'process',
#   'Did',
#   'thorough',
#   'study',
#   'and',
#   'discussions',
#   'for',
#   'system',
#   'configurations',
#   'Helped',
#   'Business',
#   'users',
#   'in',
#   'understating',
#   'the',
#   'criticality',
#   'of',
#   'data',
#   'and',
#   'providing',
#   'the',
#   'same',
#   'Been',
#   'part',
#   'of',
#   'multiple',
#   'workshops',
#   '(',
#   'Role',
#   'mapping',
#   'Market',
#   'preparations',
#   'DIL',
#   '(',
#   'Day',
#   'In',
#   'Life',
#   ')',
#   'for',
#   'business',
#   'users',
#   'etc',
#   '.',
#   ')'],
#  ['at',
#   'their',
#   'locations',
#   'Hyper',
#   'care',
#   'support',
#   'to',
#   'the',
#   'business',
#   'after',
#   'Go-Live',
#   'for',
#   'running',
#   'system',
#   'efficiently',
#   'for',
#   'SNP/GATP',
#   'Making',
#   'sure',
#   'with',
#   'other',
#   'teams',
#   '(',
#   'W',
#   '&',
#   'D',
#   'O2C',
#   'R2R',
#   'CF',
#   'P2P',
#   ')',
#   'that',
#   'all',
#   'are',
#   'in',
#   'sync',
#   'for',
#   'the',
#   'information',
#   'and',
#   'concerns',
#   'are',
#   'well',
#   'discussed',
#   'and',
#   'sorted',
#   'out',
#   'on',
#   'time',
#   'Role',
#   ':',
#   'SAP',
#   'Consultant',
#   'Project',
#   'Details',
#   ':',
#   '-',
#   'SAP',
#   'IBP',
#   'Part',
#   'of',
#   'POC',
#   'team',
#   'for',
#   'client',
#   'demonstration',
#   'Created',
#   'document',
#   'and',
#   'prepared',
#   'new',
#   'resources',
#   'for',
#   'IBP',
#   'Analyzed',
#   'and',
#   'presented',
#   'benefit',
#   'of',
#   'SAP',
#   'IBP',
#   'over',
#   'other',
#   'competitors',
#   'Bristlecone',
#   '(',
#   'Oct',
#   '’',
#   '15-May',
#   '’',
#   '16',
#   ')',
#   '.'],
#  ['Role',
#   ':',
#   'SAP',
#   'Senior',
#   'Consultant',
#   'Project',
#   'Details',
#   ':',
#   'Semtech-',
#   'Leading',
#   'Semiconductor',
#   'Company',
#   'Worked',
#   'on',
#   'different',
#   'modules',
#   'of',
#   'SAP',
#   'APO',
#   'Demand',
#   'Planning',
#   'CTM',
#   'GATP',
#   'Understanding',
#   'the',
#   'complete',
#   'process',
#   'from',
#   'Forecast',
#   'of',
#   'wafer',
#   'to',
#   'Finished',
#   'good',
#   'including',
#   'probe',
#   'binning',
#   'and',
#   'assembly',
#   'and',
#   'providing',
#   'the',
#   'solution',
#   'for',
#   'problems/errors',
#   'Doing',
#   'enhancement',
#   'as',
#   'per',
#   'the',
#   'business',
#   'needs',
#   'to',
#   'come',
#   'up',
#   'with',
#   'better',
#   'and',
#   'suitable',
#   'solution',
#   'Hyper',
#   'care',
#   'support',
#   'to',
#   'business',
#   'problems',
#   'for',
#   'DP',
#   'CTM',
#   'GATP',
#   'End',
#   'User',
#   'Training',
#   'Manual',
#   'preparation',
#   '.'],
#  ['Training',
#   'Core',
#   'Team',
#   'and',
#   'End',
#   'Users',
#   'Point',
#   'of',
#   'contact',
#   'for',
#   'APO',
#   'with',
#   'other',
#   'teams',
#   '(',
#   'Sales',
#   '&',
#   'Distribution',
#   'Production',
#   'Planning',
#   ')',
#   'whenever',
#   'there',
#   'is',
#   'need',
#   'for',
#   'system',
#   'alignment',
#   'Role',
#   ':',
#   'SAP',
#   'IBP',
#   'Consultant',
#   'Worked',
#   'as',
#   'configuration',
#   'team',
#   'member',
#   'for',
#   'SAP',
#   'IBP',
#   'project',
#   'Preparing',
#   'help',
#   'documents',
#   'and',
#   'educating',
#   'end',
#   'customers',
#   'Accenture',
#   'Ltd',
#   '(',
#   'Oct',
#   '’',
#   '14-Oct',
#   '’',
#   '15',
#   ')',
#   '.'],
#  ['Role', ':', 'SAP', 'Consultant', 'in', 'Supply', 'Chain', '.'],
#  ['Project',
#   'Details',
#   ':',
#   'Pfizer-',
#   'Pharmaceutical',
#   'Company',
#   'Understanding',
#   'business',
#   'process',
#   'and',
#   'helping',
#   'other',
#   'team',
#   'members',
#   'to',
#   'understand',
#   'them',
#   'Providing',
#   'solutions',
#   'to',
#   'issue',
#   'faced',
#   'by',
#   'business',
#   'on',
#   'daily',
#   'basis',
#   'Coordinating',
#   'with',
#   'other',
#   'Modules',
#   'within',
#   'Project',
#   'team',
#   'and',
#   'Business',
#   'teams',
#   'for',
#   'Integration',
#   'of',
#   'business',
#   'processes',
#   'Coordinated',
#   'with',
#   'planners',
#   'and',
#   'Material',
#   'master',
#   'data',
#   'group',
#   'for',
#   'mass',
#   'maintenance',
#   'of',
#   'PDS',
#   'Role',
#   ':',
#   'SAP',
#   'Consultant',
#   'in',
#   'Supply',
#   'Chain',
#   '.'],
#  ['Project',
#   'Details',
#   ':',
#   'SAP',
#   'IBP',
#   '(',
#   'S',
#   '&',
#   'OP',
#   ')',
#   'Learnt',
#   'SAP',
#   'IBP',
#   'and',
#   'prepared',
#   'more',
#   'than',
#   '50',
#   'knowledge',
#   'docs',
#   'for',
#   'SAP',
#   'IBP',
#   'which',
#   'can',
#   'be',
#   'used',
#   'extensively',
#   'in',
#   'project',
#   'Trained',
#   'and',
#   'monitored',
#   'new',
#   'resources',
#   'on',
#   'IBP',
#   'to',
#   'help',
#   'in',
#   'upcoming',
#   'assignments',
#   'Infosys',
#   'Technologies',
#   'Ltd',
#   '(',
#   'June',
#   '’',
#   '11-Oct',
#   '’',
#   '14',
#   ')',
#   '.'],
#  ['Role', ':', 'SAP', 'Consultant', 'in', 'Supply', 'Chain', '.'],
#  ['Project',
#   'Details',
#   ':',
#   'AstraZeneca-',
#   'Pharmaceutical',
#   'Company',
#   'Worked',
#   'for',
#   'UK',
#   'based',
#   'Pharmaceutical',
#   'client',
#   'handling',
#   'supply',
#   'chain',
#   'processes',
#   'in',
#   'multiple',
#   'client',
#   'location',
#   'like',
#   'Brazil',
#   'UK',
#   'Australia',
#   'USA',
#   'Sweden',
#   'and',
#   'Germany',
#   '.'],
#  ['Work',
#   'profiles',
#   'included',
#   'dealing',
#   'with',
#   'Global',
#   'clients',
#   'understanding',
#   'their',
#   'supply',
#   'chain',
#   'processes',
#   'and',
#   'collecting',
#   'the',
#   'requirements',
#   'and',
#   'helping',
#   'out',
#   'core',
#   'interface',
#   'team',
#   'members',
#   'in',
#   'understanding',
#   'the',
#   'processes',
#   'and',
#   'resolving',
#   'the',
#   'issues',
#   'in',
#   'APO',
#   '.'],
#  ['Client',
#   'follows',
#   'various',
#   'indigenous',
#   'supply',
#   'chain',
#   'processes',
#   'which',
#   'are',
#   'implemented',
#   'in',
#   'APO',
#   '.'],
#  ['Work',
#   'profile',
#   'also',
#   'includes',
#   'understanding',
#   'those',
#   'processes',
#   'in',
#   'detail',
#   'from',
#   'client',
#   'and',
#   'help',
#   'client',
#   'in',
#   'optimizing',
#   'their',
#   'processes',
#   'efficiency',
#   '.'],
#  ['Understanding',
#   'of',
#   'various',
#   'Demand',
#   'Planning',
#   'flow',
#   'from',
#   'the',
#   'central',
#   'node',
#   'to',
#   'the',
#   'different',
#   'ERP',
#   'across',
#   'the',
#   'globe',
#   '.'],
#  ['Analyzing',
#   'the',
#   'existing',
#   'supply',
#   'chain',
#   'processes',
#   'and',
#   'recommending',
#   'process',
#   'optimization',
#   '.'],
#  ['Understanding',
#   'the',
#   'flow',
#   'of',
#   'various',
#   'orders',
#   'like',
#   'Sales',
#   'order',
#   'Purchase',
#   'order',
#   'Stock',
#   'transport',
#   'requisition',
#   'and',
#   'stock',
#   'transport',
#   'orders',
#   'and',
#   'implementing',
#   'the',
#   'same',
#   'in',
#   'various',
#   'scenarios',
#   'like',
#   'same',
#   'ERP',
#   'and',
#   'cross',
#   'ERP',
#   '.'],
#  ['Understanding',
#   'the',
#   'various',
#   'mapping',
#   'strategies',
#   'followed',
#   'by',
#   'client',
#   'and',
#   'assisting',
#   'the',
#   'team',
#   'in',
#   'trouble',
#   'shooting',
#   'the',
#   'APO-R3',
#   'related',
#   'issues',
#   '.'],
#  ['Vendor',
#   'management',
#   'and',
#   'implementing',
#   'various',
#   'processes',
#   'in',
#   'appropriate',
#   'scenarios',
#   'like',
#   'vendor',
#   'managed',
#   'inventory',
#   'and',
#   'Customer',
#   'managed',
#   'inventory',
#   '.'],
#  ['Implementation',
#   'of',
#   'transportation',
#   'lanes',
#   'between',
#   'various',
#   'locations',
#   'in',
#   'APO',
#   '.'],
#  ['Worked',
#   'on',
#   'Deployment',
#   'and',
#   'TLB',
#   'Winter',
#   'internship',
#   'American',
#   'Towers',
#   'Corporation',
#   'Dept',
#   ':',
#   'Operations',
#   '(',
#   'Feb',
#   '’',
#   '11',
#   'to',
#   'May',
#   '’',
#   '11',
#   ')',
#   'Project',
#   'Title',
#   ':',
#   'Reduction',
#   'of',
#   'OPEX',
#   '–',
#   'Operating',
#   'Expenses',
#   'at',
#   'telecom',
#   'infrastructure',
#   'sites',
#   'Highlights',
#   ':',
#   'Design',
#   'of',
#   'complete',
#   'Training',
#   'Manual',
#   'for',
#   'operations',
#   '&',
#   'maintenance',
#   'and',
#   'check',
#   'list',
#   'for',
#   'telecom',
#   'sites',
#   'Cost',
#   'benefit',
#   'analysis',
#   'of',
#   'solar',
#   'power',
#   'implementation',
#   'at',
#   'telecom',
#   'sites',
#   'Standardization',
#   'of',
#   'business',
#   'process',
#   'for',
#   'prevention',
#   'of',
#   'loss',
#   'in',
#   'integrity',
#   'and',
#   'productivity',
#   'Implemented',
#   'ways',
#   'to',
#   'prevent',
#   'Pilferage',
#   'and',
#   'better',
#   'output',
#   'in',
#   'telecom',
#   'services',
#   'Suggested',
#   'and',
#   'provided',
#   'the',
#   'feasibility',
#   'of',
#   'Solar',
#   'power',
#   'implementation',
#   'telecom',
#   'sites',
#   'summer',
#   'internship',
#   'Subros',
#   'Ltd.Dept',
#   ':',
#   'Supply',
#   'Chain',
#   'and',
#   'Industrial',
#   'Operations',
#   '(',
#   'Apr',
#   '’',
#   '10',
#   'to',
#   'Jun',
#   '’',
#   '10',
#   ')',
#   'Project',
#   'Title',
#   ':',
#   'GRC',
#   'Risk',
#   'Governance',
#   'and',
#   'Compliance',
#   '–',
#   'SAP',
#   'Highlights',
#   ':',
#   'Analyzed',
#   'the',
#   'process',
#   'to',
#   'identify',
#   'the',
#   'operation',
#   'roles',
#   'and',
#   'policies',
#   'across',
#   'the',
#   'entire',
#   'business',
#   'Compared',
#   'duties',
#   'in',
#   'procurement',
#   'and',
#   'manufacturing',
#   'to',
#   'reduce',
#   'lead',
#   'time',
#   'and',
#   'conflicts',
#   'Implemented',
#   'Process',
#   'Control',
#   'to',
#   'manage',
#   'risk',
#   'and',
#   'to',
#   'comply',
#   'with',
#   'the',
#   'Sarbanes-Oxley',
#   'Act',
#   'Curtailed',
#   'Role',
#   'violations',
#   'from',
#   '15214',
#   'to',
#   '904',
#   'and',
#   'made',
#   'recommendations',
#   'for',
#   'improvements',
#   '.'],
#  ['Reduced',
#   'administrative',
#   'cost',
#   'and',
#   'risks',
#   'with',
#   'corporate',
#   'governance',
#   'also',
#   'leading',
#   'to',
#   'faster',
#   'audits',
#   'MIS',
#   '(',
#   'Management',
#   'Information',
#   'System',
#   ')',
#   'for',
#   'ERP',
#   'access',
#   'review',
#   'and',
#   'control',
#   'Work',
#   'Experience',
#   '(',
#   'Pre',
#   'Mba',
#   ')',
#   'Satyam',
#   'Computer',
#   'Services',
#   '(',
#   'Mar',
#   '’',
#   '06',
#   'to',
#   'Oct',
#   '’',
#   '09',
#   ')',
#   'Worked',
#   'as',
#   'a',
#   'Team',
#   'Lead',
#   'for',
#   'a',
#   'cross',
#   'functional',
#   'team',
#   'of',
#   'IT',
#   'staff',
#   'and',
#   'functional',
#   'managers',
#   'Understanding',
#   'requirement',
#   'and',
#   'procurement',
#   'of',
#   'material',
#   'for',
#   'final',
#   'product',
#   'Effectively',
#   'handled',
#   'client',
#   'interaction',
#   'leading',
#   'to',
#   'faster',
#   'problem',
#   'resolution',
#   'and',
#   'increased',
#   'customer',
#   'satisfaction',
#   'Developed',
#   'the',
#   'software',
#   'for',
#   'enhanced',
#   'operations',
#   'maintenance',
#   'and',
#   'analysis',
#   'of',
#   'data',
#   'Reduced',
#   'human',
#   'intervention',
#   'in',
#   'vehicles',
#   'by',
#   'developing',
#   'automated',
#   'techniques',
#   'and',
#   'better',
#   'design',
#   'Involved',
#   'in',
#   'the',
#   'Mentoring',
#   'and',
#   'knowledge',
#   'transferring',
#   'of',
#   'new',
#   'recruits',
#   'into',
#   'the',
#   'project',
#   'Received',
#   'client',
#   'appreciation',
#   'for',
#   'automating',
#   'testing',
#   'process',
#   'which',
#   'Reduced',
#   'the',
#   'Manual',
#   'Efforts',
#   'by',
#   '75',
#   '%',
#   'ACHIEVEMENTS',
#   'Achieved',
#   'highest',
#   'rating',
#   'consecutively',
#   'for',
#   'two',
#   'years',
#   'for',
#   'performance',
#   'in',
#   'Projects',
#   'Received',
#   'Client',
#   'Appreciation',
#   'for',
#   'an',
#   'Outstanding',
#   'Contribution',
#   'towards',
#   'the',
#   'project',
#   'Education',
#   'Technical',
#   'Skills',
#   'Modeling',
#   'tools',
#   ':',
#   'MS',
#   'Visio',
#   'Utilities',
#   ':',
#   'MS',
#   'office',
#   ':',
#   'MS',
#   'Excel',
#   '&',
#   'MS',
#   'power',
#   'point',
#   'MS',
#   'project',
#   'Languages',
#   ':',
#   'C',
#   'C++',
#   'Operation',
#   'system',
#   ':',
#   'Windows',
#   'Mac',
#   'OS',
#   'X',
#   'linux',
#   'certifications',
#   'and',
#   'trainings',
#   'Achievements',
#   'Co-curricular',
#   '&',
#   'Extra-curricular',
#   'Won',
#   'Prizes',
#   'for',
#   'sketching',
#   'and',
#   'painting',
#   'during',
#   'different',
#   'events',
#   'Conducted',
#   'Yoga',
#   'classes',
#   'at',
#   'organization',
#   'Chandra',
#   'Sekhar',
#   'MailID',
#   ':',
#   'csp.lalitha',
#   '@',
#   'gmail.com',
#   'Contact',
#   ':',
#   '+91-9066715639',
#   'Career',
#   'Objective',
#   'I',
#   'am',
#   'looking',
#   'for',
#   'a',
#   'challenging',
#   'position',
#   'to',
#   'utilize',
#   'my',
#   'skills',
#   'and',
#   'talents',
#   'in',
#   'the',
#   'field',
#   'of',
#   'Information',
#   'Technology',
#   'that',
#   'offers',
#   'professional',
#   'growth',
#   'while',
#   'being',
#   'resourceful',
#   'innovative',
#   'and',
#   'flexible',
#   '.'],
#  ['Summary',
#   'Having',
#   '7',
#   'years',
#   'of',
#   'total',
#   'IT',
#   'experience',
#   'in',
#   'diversified',
#   'fields',
#   'of',
#   'career',
#   'in',
#   'various',
#   'Tools',
#   '.'],
#  ['4+Years',
#   'of',
#   'work',
#   'experience',
#   'in',
#   'Big',
#   'Data-Hadoop',
#   'Administration',
#   '.'],
#  ['2+',
#   'years',
#   'of',
#   'work',
#   'experience',
#   'in',
#   'Business',
#   'Intelligence',
#   'OBIEE-Administration',
#   'Tool',
#   '(',
#   'RPD',
#   '’',
#   's',
#   'and',
#   'Reports',
#   ')',
#   '.'],
#  ['Educational',
#   'Qualification',
#   'MCA',
#   '(',
#   'Master',
#   'Of',
#   'computer',
#   'Application',
#   ')',
#   'from',
#   'Periyar',
#   'University',
#   '.'],
#  ['Professional',
#   'Profile',
#   'Working',
#   'as',
#   'a',
#   'Technical',
#   'Consultant',
#   'with',
#   'Business',
#   'technology',
#   'solutions',
#   'Pvt.ltd',
#   'Since',
#   'Nov',
#   '2015',
#   'to',
#   'Tilldate',
#   '.'],
#  ['Worked',
#   'as',
#   'a',
#   'Solution',
#   'Architect',
#   'with',
#   'Bhrigus',
#   'Software',
#   '(',
#   'I',
#   ')',
#   'Pvt.Ltd',
#   'Since',
#   'Nov-2010',
#   'to',
#   'Nov-2015',
#   '.'],
#  ['Skills',
#   'Hadoop',
#   'Skills',
#   ':',
#   'Hdfs',
#   'Yarn',
#   'Hive',
#   'Pig',
#   'MapReduce',
#   'Sqoop',
#   'Ambari',
#   'Hue',
#   'Storm',
#   'Spark',
#   'Knox',
#   'Ranger',
#   'kafka',
#   '.'],
#  ['Secondary',
#   'skills1',
#   ':',
#   'Kerberos',
#   'Hue',
#   'AmbariviewsGanglia',
#   'Nagios',
#   'AmbariMetrics',
#   'and',
#   'Alerts',
#   '.'],
#  ['Databases', ':', 'My', 'SQL', 'HBase', '.'],
#  ['Operating', 'Systems', ':', 'SUSE11', 'Red', 'hat', 'Linux', '.'],
#  ['Technical',
#   'Skills',
#   'As',
#   'a',
#   'Hadoop',
#   'Admin',
#   ':',
#   '7',
#   'years',
#   'of',
#   'experience',
#   'in',
#   'Hadoop',
#   'Administration',
#   'and',
#   'Business',
#   'Intelligence',
#   'and',
#   'Big',
#   'Data',
#   'solutions',
#   '.'],
#  ['Hands',
#   'on',
#   'experience',
#   'in',
#   'implementing',
#   'and',
#   'managing',
#   'fully',
#   'functional',
#   'Secure',
#   'Hortonworks',
#   'Data',
#   'Platform',
#   '2.3.2',
#   'and',
#   '2.5-1245',
#   'Experience',
#   'in',
#   'upgrading',
#   'Ambari',
#   '1.6',
#   'to',
#   '1.7',
#   'and',
#   'Ambari',
#   '2.4.0.1to',
#   '2.4.0.7',
#   '.'],
#  ['Experience',
#   'in',
#   'upgrading',
#   'HDP',
#   '2.1.x',
#   'to',
#   'HDP',
#   '2.3.2',
#   'and',
#   'HDP2.5',
#   '.'],
#  ['Implementing',
#   'Patches',
#   'Hot',
#   'fixes',
#   'for',
#   'issues',
#   'found',
#   'on',
#   'the',
#   'platform',
#   'by',
#   'consulting',
#   'the',
#   'Product',
#   'Vendor',
#   'Prepared',
#   'Customized',
#   'scripts',
#   'for',
#   'backup',
#   'and',
#   'monitoring',
#   'the',
#   'cluster',
#   'Hands',
#   'on',
#   'experience',
#   'in',
#   'troubleshooting',
#   'Monitoring',
#   'and',
#   'Backup',
#   'recovery',
#   'of',
#   'a',
#   'Hadoop',
#   'cluster',
#   'Deep',
#   'knowledge',
#   'and',
#   'related',
#   'experience',
#   'with',
#   'Hadoop',
#   'and',
#   'its',
#   'ecosystem',
#   'components',
#   'i.e',
#   '.'],
#  ['HDFS',
#   'MapReduce',
#   'Hive',
#   'Pig',
#   'Sqoop',
#   'Oozie',
#   'HBase',
#   'Spark',
#   'Storm',
#   'Kafka',
#   'Ranger',
#   'etc',
#   '.'],
#  ['As',
#   'an',
#   'OBIEE',
#   'Admin',
#   ':',
#   'Strong',
#   'experience',
#   'in',
#   'developing',
#   'OBIEE',
#   'Repository',
#   '(',
#   '.rpd',
#   ')',
#   'at',
#   'three',
#   'layers',
#   '(',
#   'Physical',
#   'Layer',
#   'Business',
#   'Model',
#   '&',
#   'Presentation',
#   'Layer',
#   ')',
#   'Interactive',
#   'Dashboards',
#   '.'],
#  ['Experience',
#   'in',
#   'creating',
#   'users',
#   'using',
#   'OBIEE',
#   'Admin',
#   'Tool',
#   'and',
#   'Web',
#   'Catalog',
#   'Objects',
#   '(',
#   'Dashboards',
#   'Pages',
#   'and',
#   'Reports',
#   ')',
#   'using',
#   'Presentation',
#   'Services',
#   '.'],
#  ['Having',
#   'good',
#   'experience',
#   'in',
#   'rpd',
#   'and',
#   'catalog',
#   'migration',
#   'from',
#   'OBIEE',
#   '10g',
#   'to',
#   '11g',
#   '.'],
#  ['Expertise',
#   'in',
#   'creating',
#   'and',
#   'modifying',
#   'metadata',
#   'repository',
#   'using',
#   'OBIEE',
#   'Administration',
#   'Tool',
#   'to',
#   'suit',
#   'user',
#   '’',
#   's',
#   'requirement',
#   '.'],
#  ['ITI/GS',
#   '–',
#   'Hadoop',
#   'Global',
#   'Support',
#   'for',
#   'German',
#   'Automobile',
#   'Major',
#   'Nov-2015',
#   'to',
#   'Tilldate',
#   'Environment',
#   ':',
#   'Hdfs',
#   'Yarn',
#   'Hive',
#   'Ranger',
#   'Kafka',
#   'SUSE11',
#   'POSTGRES',
#   '.'],
#  ['Distribution',
#   ':',
#   'HortonworksHDP',
#   '2.1.5',
#   'Hortonworks',
#   'HDP',
#   '2.5.-1245',
#   'Role',
#   ':',
#   'Hadoop',
#   'Admin',
#   '.'],
#  ['Project',
#   'Description',
#   ':',
#   'Support',
#   'for',
#   '3',
#   'Hadoop',
#   'clusters',
#   'in',
#   'Europe',
#   'and',
#   'one',
#   'Cluster',
#   'in',
#   'the',
#   'US',
#   '.'],
#  ['ITI',
#   'GS',
#   'provides',
#   '24x7',
#   'support',
#   'for',
#   'all',
#   'the',
#   'existing',
#   'clusters',
#   'and',
#   'is',
#   'also',
#   'involved',
#   'in',
#   'building',
#   'of',
#   'new',
#   'clusters',
#   'across',
#   'the',
#   'globe',
#   '.'],
#  ['Contribution',
#   ':',
#   'Install',
#   'Configure',
#   'and',
#   'existing',
#   'clusters',
#   'in',
#   'Research',
#   'and',
#   'Development',
#   'wing',
#   'of',
#   'customer',
#   '.'],
#  ['We',
#   'are',
#   'involved',
#   'Integration',
#   'deployment',
#   'and',
#   'Production',
#   'deployment',
#   'as',
#   'per',
#   'client',
#   'requirement',
#   '.'],
#  ['Provide', '24X7', 'Support', 'to', 'the', 'Business', 'teams', '.'],
#  ['Monitor',
#   'job',
#   'performance',
#   'System',
#   'metrics',
#   'and',
#   'logs',
#   'for',
#   'any',
#   'problems',
#   '.'],
#  ['Work',
#   'along',
#   'with',
#   'the',
#   'Service',
#   'Providers',
#   'to',
#   'resolve',
#   'the',
#   'tickets',
#   'that',
#   'were',
#   'raised',
#   'by',
#   'various',
#   'business',
#   'teams',
#   '.'],
#  ['Co-ordinate', 'with', 'various', 'team', 'e.g', '.'],
#  ['OS', 'Security', 'SAT', 'to', 'resolve', 'tickets', '.'],
#  ['Co-ordinate',
#   'with',
#   'Hortonworks',
#   'team',
#   'to',
#   'fix',
#   'un-resolved',
#   'issues',
#   'on',
#   'the',
#   'platform',
#   '.'],
#  ['Upgrade', 'the', 'Ambari', 'views', 'and', 'Ambari', '.'],
#  ['Implement',
#   'new',
#   'feature',
#   '(',
#   's',
#   ')',
#   'on',
#   'the',
#   'cluster',
#   'as',
#   'per',
#   'the',
#   'business',
#   'requirement',
#   '.'],
#  ['Sprint',
#   'Nextel',
#   'May-2013',
#   'to',
#   'Nov',
#   '-2015',
#   'Environment',
#   ':',
#   'Hadoop',
#   'Apache',
#   'Pig',
#   'Hive',
#   'SQOOP',
#   'Java',
#   'Redhat',
#   'Linux',
#   'MySQL',
#   'Hue',
#   '.'],
#  ['Role', ':', 'Hadoop', 'Admin', '.'],
#  ['Description',
#   ':',
#   'Sprint',
#   'is',
#   'a',
#   'United',
#   'States',
#   'telecommunications',
#   'holding',
#   'company',
#   'that',
#   'provides',
#   'wireless',
#   'services',
#   'and',
#   'is',
#   'also',
#   'a',
#   'major',
#   'global',
#   'Internet',
#   'carrier',
#   '.'],
#  ['It',
#   'is',
#   'the',
#   'fourth',
#   'largest',
#   'U.S.',
#   'wireless',
#   'network',
#   'operator',
#   'as',
#   'of',
#   'February',
#   '2015',
#   'and',
#   'serves',
#   '55',
#   'million',
#   'customers',
#   'as',
#   'of',
#   '2015',
#   '.'],
#  ['In',
#   'addition',
#   'to',
#   'the',
#   'Sprint',
#   'brand',
#   'the',
#   'company',
#   'also',
#   'offers',
#   'wireless',
#   'voice',
#   'messaging',
#   'and',
#   'broadband',
#   'services',
#   'through',
#   'its',
#   'various',
#   'subsidiaries',
#   'under',
#   'the',
#   'Boost',
#   'Mobile',
#   'Virgin',
#   'Mobile',
#   'and',
#   'Assurance',
#   'Wireless',
#   'brands',
#   'as',
#   'well',
#   'as',
#   'wholesale',
#   'access',
#   'to',
#   'its',
#   'wireless',
#   'networks',
#   'to',
#   'mobile',
#   'virtual',
#   'network',
#   'operators',
#   '.'],
#  ['Storing',
#   'millions',
#   'of',
#   'mobile',
#   'call',
#   'records',
#   'and',
#   'providing',
#   'real',
#   'time',
#   'access',
#   'to',
#   'the',
#   'call',
#   'records',
#   'and',
#   'billing',
#   'information',
#   'to',
#   'customers',
#   '.'],
#  ['Traditional',
#   'storage/database',
#   'systems',
#   'could',
#   "n't",
#   'scale',
#   'to',
#   'the',
#   'loads',
#   'and',
#   'provide',
#   'a',
#   'cost',
#   'effective',
#   'solution',
#   '.'],
#  ['Sprint',
#   'generates',
#   'and',
#   'stores',
#   'a',
#   'large',
#   'amount',
#   'of',
#   'data',
#   '.'],
#  ['Since',
#   'the',
#   'data',
#   'is',
#   'huge',
#   'manual',
#   'analysis',
#   'of',
#   'the',
#   'data',
#   'is',
#   'difficult',
#   '.'],
#  ['The',
#   'need',
#   'to',
#   'handle',
#   'such',
#   'large',
#   'volumes',
#   'of',
#   'data',
#   'leads',
#   'to',
#   'the',
#   'Big',
#   'Data',
#   'Concepts',
#   'and',
#   'data',
#   'analysis',
#   'using',
#   'hadoop',
#   '.'],
#  ['Responsibilities',
#   ':',
#   'Involved',
#   'in',
#   'Hadoop',
#   'Cluster',
#   'environment',
#   'cluster',
#   'capacity',
#   'planning',
#   'performance',
#   'tuning',
#   'cluster',
#   'Monitoring',
#   'Troubleshooting',
#   '.'],
#  ['Supported',
#   'Map',
#   'Reduce',
#   'Programs',
#   'those',
#   'are',
#   'running',
#   'on',
#   'the',
#   'cluster',
#   '.'],
#  ['Involved',
#   'in',
#   'HDFS',
#   'maintenance',
#   'and',
#   'administering',
#   'it',
#   'through',
#   'Hadoop-Java',
#   'API',
#   '.'],
#  ['Installed',
#   'various',
#   'Hadoop',
#   'Ecosystems',
#   'and',
#   'Hadoop',
#   'Daemons',
#   '.'],
#  ['Configured',
#   'various',
#   'property',
#   'files',
#   'like',
#   'core-site.xml',
#   'hdfs-site.xml',
#   'mapred-',
#   'site.xml',
#   'and',
#   'hadoop-env.xml',
#   'based',
#   'upon',
#   'the',
#   'job',
#   'requirement',
#   '.'],
#  ['Importing',
#   'and',
#   'exporting',
#   'data',
#   'into',
#   'HDFS',
#   'using',
#   'Sqoop',
#   '.'],
#  ['Loading', 'log', 'data', 'directly', 'into', 'HDFS', 'using', 'Flume', '.'],
#  ['Experienced',
#   'in',
#   'managing',
#   'and',
#   'reviewing',
#   'Hadoop',
#   'log',
#   'files',
#   'Maintaining',
#   'Backup',
#   'for',
#   'name',
#   'node',
#   '.'],
#  ['Performed',
#   'Name',
#   'node',
#   'recoveries',
#   'from',
#   'previous',
#   'backups',
#   'Adding',
#   'new',
#   'nodes',
#   'to',
#   'an',
#   'existing',
#   'cluster',
#   '.'],
#  ['Recovering', 'from', 'a', 'NameNode', 'failure', '.'],
#  ['Decommissioning',
#   'and',
#   'commissioning',
#   'the',
#   'Node',
#   'on',
#   'running',
#   'cluster',
#   '.'],
#  ['OCDM',
#   'Jan',
#   '-2012',
#   'to',
#   'Mar-2013',
#   'Environment',
#   ':',
#   'OBIEE',
#   '11.1.1.7',
#   'Sql',
#   '.'],
#  ['Role', ':', 'OBIEE', 'Developer', '.'],
#  ['Oracle',
#   'Communications',
#   'Data',
#   'Model',
#   'is',
#   'a',
#   'standards-based',
#   'pre-built',
#   'approach',
#   'to',
#   'communications',
#   'data',
#   'warehousing',
#   'enabling',
#   'a',
#   'communications',
#   'company',
#   'to',
#   'realize',
#   'the',
#   'power',
#   'of',
#   'insight',
#   'more',
#   'quickly',
#   '.'],
#  ['Oracle',
#   'Communications',
#   'Data',
#   'Model',
#   'reduces',
#   'costs',
#   'for',
#   'both',
#   'immediate',
#   'and',
#   'on-going',
#   'operations',
#   'by',
#   'leveraging',
#   'out-of-box',
#   'Oracle',
#   'based',
#   'DW/BI',
#   'solutions',
#   'making',
#   'world-class',
#   'database',
#   'and',
#   'business',
#   'intelligence',
#   'technology',
#   'solutions',
#   'available',
#   'with',
#   'a',
#   'communications',
#   'specific',
#   'data',
#   'model',
#   '.'],
#  ['Oracle',
#   'Communications',
#   'Data',
#   'Model',
#   'offers',
#   'a',
#   'single-vendor',
#   'solution',
#   'package',
#   'that',
#   'is',
#   'tightly',
#   'integrated',
#   'with',
#   'the',
#   'business',
#   'intelligence',
#   'platform',
#   '.'],
#  ['With',
#   'pre-built',
#   'data',
#   'mining',
#   'On-line',
#   'Analytical',
#   'Processing',
#   '(',
#   'OLAP',
#   ')',
#   'and',
#   'dimensional',
#   'models',
#   'Oracle',
#   'Communications',
#   'Data',
#   'Model',
#   'provides',
#   'you',
#   'with',
#   'industry-specific',
#   'metrics',
#   'and',
#   'insights',
#   'that',
#   'you',
#   'can',
#   'act',
#   'on',
#   'immediately',
#   'to',
#   'improve',
#   'your',
#   'bottom',
#   'line',
#   '.'],
#  ['These',
#   'business',
#   'intelligence',
#   'solution',
#   'offerings',
#   'take',
#   'advantage',
#   'of',
#   'Oracle',
#   "'s",
#   'scalability',
#   'and',
#   'reliability',
#   'using',
#   'Oracle',
#   "'s",
#   'familiar',
#   'optimization',
#   'parallelism',
#   'and',
#   'performance',
#   'engineering',
#   'within',
#   'the',
#   'database',
#   '.'],
#  ['Responsibilities',
#   ':',
#   'Working',
#   'closely',
#   'with',
#   'Business',
#   'Analyst',
#   'in',
#   'understanding',
#   'the',
#   'Analytics',
#   'requirements',
#   'a',
#   'developed',
#   'and',
#   'physical',
#   'layer',
#   'Business',
#   'Layer',
#   'and',
#   'Presentation',
#   'Layer',
#   'of',
#   'OBIEE',
#   '11g',
#   '.'],
#  ['Developed',
#   'BI',
#   'Metadata',
#   'Reports',
#   'and',
#   'Dashboards',
#   'using',
#   'OBIEE',
#   '11g',
#   '.'],
#  ['Understanding',
#   'the',
#   'requirements',
#   'of',
#   'the',
#   'client',
#   'business',
#   'scenario',
#   '(',
#   's',
#   ')',
#   '.'],
#  ['Experience',
#   'in',
#   'creation',
#   'of',
#   'logical',
#   'columns',
#   'hierarchies',
#   'level',
#   'based',
#   'measures',
#   'in',
#   'Business',
#   'model',
#   '.'],
#  ['Design', 'various', 'reports', 'i.e', '.'],
#  ['Drill',
#   'down',
#   'Pivot',
#   'Narrative',
#   'and',
#   'Nested',
#   'Reports',
#   'in',
#   'Answers',
#   'and',
#   'Customer',
#   'demography',
#   'with',
#   'the',
#   'facility',
#   'to',
#   'drilldown',
#   'and',
#   'charts',
#   'Ability',
#   'to',
#   'assemble',
#   'corporate',
#   'KPIs',
#   'into',
#   'actionable',
#   'dashboards',
#   '&',
#   'detailed',
#   'reports',
#   '.'],
#  ['Proficiency',
#   'with',
#   'Answers',
#   'Dashboards',
#   'Reporting',
#   'and',
#   'Publishing',
#   'using',
#   'the',
#   'BI',
#   'Server',
#   '.'],
#  ['Insurance',
#   'Management',
#   'Dec-2010',
#   'to',
#   'Dec-2011',
#   'Client',
#   ':',
#   'MetLife',
#   'Role',
#   ':',
#   'OBIEE',
#   'Developer',
#   '.'],
#  ['Environment', ':', 'OBIEE', '10g', 'Oracle', '.'],
#  ['Project',
#   'Overview',
#   ':',
#   'Met',
#   'life',
#   'Inc',
#   'operates',
#   'through',
#   'its',
#   'affiliates',
#   'and',
#   'subsidiaries',
#   'as',
#   'a',
#   'provider',
#   'of',
#   'insurance',
#   'and',
#   'other',
#   'financial',
#   'services',
#   'to',
#   'individual',
#   'and',
#   'institutional',
#   'customers',
#   '.'],
#  ['The',
#   'Company',
#   'offers',
#   'life',
#   'insurance',
#   'annuities',
#   'automobiles',
#   'and',
#   'property',
#   'insurance',
#   'funds',
#   'to',
#   'individuals',
#   'as',
#   'well',
#   'as',
#   'group',
#   'insurance',
#   'reinsurance',
#   'retirement',
#   'and',
#   'services',
#   'to',
#   'corporations',
#   'and',
#   'other',
#   'institutions',
#   '.'],
#  ['The',
#   'met',
#   'life',
#   'companies',
#   'serve',
#   'approximately',
#   '12',
#   'million',
#   'individuals',
#   'and',
#   '33',
#   'million',
#   'employees',
#   'and',
#   'organized',
#   'into',
#   'six',
#   'major',
#   'segments',
#   ':',
#   'individual',
#   'institutional',
#   'reinsurance',
#   'auto',
#   'and',
#   'home',
#   'asset',
#   'management',
#   '.'],
#  ['Roles',
#   'and',
#   'Responsibilities',
#   ':',
#   'Working',
#   'closely',
#   'with',
#   'Business',
#   'Analyst',
#   'in',
#   'understanding',
#   'the',
#   'Analytics',
#   'requirements',
#   'and',
#   'developed',
#   'physical',
#   'layer',
#   'Business',
#   'Layer',
#   'and',
#   'Presentation',
#   'Layer',
#   'of',
#   'OBIEE',
#   '.'],
#  ['Developed',
#   'BI',
#   'Metadata',
#   'Reports',
#   'and',
#   'Dashboards',
#   'using',
#   'OBIEE',
#   '/',
#   'Siebel',
#   'Analytics',
#   '.'],
#  ['Defining',
#   'Multiple',
#   'Dimension',
#   'Hierarchies',
#   'for',
#   'the',
#   'Dimension',
#   'Logical',
#   'Table',
#   'and',
#   'also',
#   'Experience',
#   'in',
#   'creation',
#   'of',
#   'logical',
#   'columns',
#   'hierarchies',
#   'level',
#   'based',
#   'measures',
#   'in',
#   'Business',
#   'model',
#   '.'],
#  ['Proficiency',
#   'with',
#   'Answers',
#   'Dashboards',
#   'Reporting',
#   'and',
#   'Publishing',
#   'using',
#   'the',
#   'BI',
#   'Server',
#   '.'],
#  ['Extensively',
#   'used',
#   'Variables',
#   '(',
#   'repository',
#   'and',
#   'presentation',
#   ')',
#   'in',
#   'the',
#   'process',
#   'of',
#   'making',
#   'the',
#   'reports',
#   '.'],
#  ['Creating', 'the', 'Dashboard', 'and', 'Report', 'level', 'prompts', '.'],
#  ['Configured',
#   'to',
#   'deliver',
#   'analytics',
#   'content',
#   'based',
#   'on',
#   'schedule',
#   'obtain',
#   'weekly',
#   'reports',
#   'and',
#   'sent',
#   'notification',
#   'Alerts',
#   '.'],
#  ['SUMMARY',
#   ':',
#   'Dynamic',
#   'Passion',
#   'of',
#   '5.2',
#   'years',
#   'of',
#   'experience',
#   'in',
#   'Development',
#   'Maintenance',
#   'and',
#   'Production',
#   'Support',
#   'Analyst',
#   'in',
#   'Insurance',
#   'Logistics',
#   'HealthCare',
#   'and',
#   'Telecom',
#   'Domains',
#   '.'],
#  ['5.2',
#   'years',
#   'of',
#   'experience',
#   'in',
#   'software',
#   'system',
#   'development',
#   'life',
#   'cycle',
#   '(',
#   'SDLC',
#   ')',
#   'using',
#   'Power',
#   'Builder',
#   'Oracle',
#   'and',
#   'Sybase',
#   '.'],
#  ['Experience',
#   'in',
#   'Requirements',
#   'Analysis',
#   'Design',
#   'Development',
#   'and',
#   'Maintenance',
#   'of',
#   'application',
#   'software',
#   '.'],
#  ['Working',
#   'experience',
#   'in',
#   'design',
#   'implementation',
#   'and',
#   'support/maintenance',
#   'of',
#   'applications',
#   'using',
#   'PowerBuilder/Sybase',
#   'and',
#   'Oracle',
#   '.'],
#  ['Strong',
#   'Analytical',
#   'Problem',
#   'solving',
#   'excellent',
#   'Inter-Personal',
#   'Communication',
#   'skills',
#   'and',
#   'Flexible',
#   'to',
#   'learn',
#   'new',
#   'technologies',
#   'in',
#   'the',
#   'IT',
#   'industry',
#   'towards',
#   'company',
#   '’',
#   's',
#   'success',
#   'rate',
#   '.'],
#  ['Experience',
#   'in',
#   'code',
#   'enhancements',
#   'using',
#   'PowerBuilder',
#   'and',
#   'Sybase',
#   '.'],
#  ['Having',
#   'a',
#   'strong',
#   'background',
#   'in',
#   'debugging',
#   'the',
#   'application',
#   'using',
#   'Power',
#   'Builder',
#   '.'],
#  ['Having',
#   'database',
#   'experience',
#   'using',
#   'Sybase',
#   'and',
#   'Oracle',
#   '10g/11g',
#   'SQL',
#   'PL/SQL',
#   'DDL',
#   'DML',
#   'Stored',
#   'Procedures',
#   'Functions',
#   'Constraints',
#   'Triggers',
#   '.'],
#  ['Direct', 'Interaction', 'with', 'the', 'clients', '.'],
#  ['Having',
#   'knowledge',
#   'in',
#   'Logistics',
#   'Health',
#   'care',
#   'Insurance',
#   'and',
#   'Telecom',
#   'domains',
#   '.'],
#  ['EDUCATION',
#   'QUALIFICATIONS',
#   'EXPERIENCE',
#   'SUMMARY',
#   ':',
#   'Currently',
#   'working',
#   'with',
#   'IBM',
#   '--',
#   '-',
#   'Feb-2016',
#   'to',
#   'till',
#   'date',
#   'Previously',
#   'worked',
#   'with',
#   'iGATE',
#   'Global',
#   'Solutions',
#   '--',
#   '--',
#   'Mar-2015',
#   'to',
#   'Sep-',
#   '2015',
#   'Previously',
#   'worked',
#   'with',
#   'Adecco',
#   'India',
#   'PVT',
#   'LITD',
#   '--',
#   '-',
#   'May-2014',
#   'to',
#   'Feb-2015',
#   'Previously',
#   'worked',
#   'with',
#   'Zylog',
#   'Systems',
#   'Limited',
#   '--',
#   '-',
#   'Sep-2011',
#   'to',
#   'June-2013',
#   'TECHNICAL',
#   'EXPERIENCE',
#   ':',
#   'FUNCTIONAL',
#   'EXPERIENCE',
#   ':',
#   'PROJECT',
#   'DETAILS',
#   ':',
#   'Brief',
#   'description',
#   'of',
#   'the',
#   'project',
#   ':',
#   'CORE',
#   'stands',
#   'for',
#   'Customer',
#   'Order',
#   'Entry',
#   '.'],
#  ['CORE',
#   'was',
#   'first',
#   'designed',
#   'to',
#   'enhance',
#   'LCI',
#   "'s",
#   'customer',
#   'order',
#   'entry',
#   'system',
#   'enabling',
#   'people',
#   'to',
#   'key',
#   'dedicated',
#   'orders',
#   'and',
#   'provision',
#   'those',
#   'orders',
#   'through',
#   'a',
#   'workflow',
#   'process',
#   '.'],
#  ['Because',
#   'of',
#   'the',
#   'advantages',
#   'of',
#   'the',
#   'workflow',
#   'process',
#   'in',
#   'CORE',
#   'Network',
#   'Optimization',
#   'began',
#   'to',
#   'use',
#   'CORE',
#   'to',
#   'order',
#   'and',
#   'provision',
#   'the',
#   'installation',
#   'of',
#   'circuits',
#   'and',
#   'equipment',
#   'to',
#   'enhance',
#   'LCI',
#   "'s",
#   'network',
#   'Responsible',
#   'for',
#   ':',
#   'Requirements',
#   'gathering',
#   'Enhancements',
#   'and',
#   'customization',
#   'of',
#   'existing',
#   'software',
#   'in',
#   'all',
#   'phases',
#   'in',
#   'the',
#   'life',
#   'cycle',
#   'of',
#   'application',
#   'development',
#   'and',
#   'Bug',
#   'fixing',
#   '.'],
#  ['Implementation',
#   'of',
#   'the',
#   'application',
#   'on',
#   'Production',
#   'Server',
#   'Prepared',
#   'root',
#   'cause',
#   'analysis',
#   'for',
#   'problems',
#   'occurred',
#   'Preparation',
#   'of',
#   'LLA',
#   'Created',
#   'Procedures',
#   'Triggers',
#   'Functions',
#   'and',
#   'Packages',
#   '.'],
#  ['Coordinated',
#   'physical',
#   'changes',
#   'to',
#   'computer',
#   'data',
#   'bases',
#   'codes',
#   'tested',
#   'and',
#   'implemented',
#   'Oracle',
#   'and',
#   'SQL',
#   'data',
#   'base',
#   'applying',
#   'knowledge',
#   'of',
#   'data',
#   'base',
#   'management',
#   'system',
#   '.'],
#  ['Brief',
#   'description',
#   'of',
#   'the',
#   'project',
#   ':',
#   'Charlie',
#   'is',
#   'a',
#   '24/7/365',
#   'Claims',
#   'application',
#   'for',
#   'Auto',
#   'Home',
#   'and',
#   'Boat',
#   'applications',
#   '.'],
#  ['There',
#   'are',
#   'around',
#   '2200',
#   'users',
#   'for',
#   'Charlie',
#   'at',
#   'peak',
#   '1600',
#   'concurrent',
#   'users',
#   '.'],
#  ['Charlie',
#   'and',
#   'CAF',
#   '(',
#   'Claims',
#   'Activity',
#   'File',
#   ')',
#   'are',
#   'the',
#   'claims',
#   'systems',
#   'that',
#   'together',
#   'form',
#   'the',
#   'MetLife',
#   'Auto',
#   '&',
#   'Home',
#   'Claims',
#   'system',
#   '.'],
#  ['Charlie',
#   'is',
#   'a',
#   'real',
#   'time',
#   'online',
#   'system',
#   'which',
#   'is',
#   'used',
#   'to',
#   'key',
#   'in',
#   'the',
#   'Claims',
#   'details',
#   '.'],
#  ['The',
#   'Charlie',
#   'system',
#   'uses',
#   'VB',
#   'and',
#   'Power',
#   'Builder',
#   'and',
#   'is',
#   'a',
#   'front-end',
#   'system',
#   'supported',
#   'by',
#   'highly',
#   'relational',
#   'Sybase',
#   'ASE',
#   'databases',
#   '.'],
#  ['Whereas',
#   'the',
#   'CAF',
#   'system',
#   'is',
#   'a',
#   'backend',
#   'system',
#   'and',
#   'consists',
#   'of',
#   'CICS/VSAM',
#   'Primary',
#   'Users',
#   'to',
#   'the',
#   'Charlie',
#   'applications',
#   'are',
#   'located',
#   'in',
#   'the',
#   'Field',
#   'Claims',
#   'Offices',
#   '(',
#   'FCO',
#   ')',
#   'who',
#   'logs',
#   'the',
#   'claim',
#   'on',
#   'to',
#   'the',
#   'system',
#   'Internet',
#   'Strategy',
#   'project',
#   'is',
#   'planned',
#   'for',
#   'providing',
#   'additional',
#   'eService',
#   'functionality',
#   'to',
#   'insured',
#   '’',
#   's',
#   'and',
#   'agents',
#   '.'],
#  ['Responsible',
#   'for',
#   ':',
#   'Requirements',
#   'gathering',
#   'Enhancements',
#   'and',
#   'customization',
#   'of',
#   'existing',
#   'software',
#   'in',
#   'all',
#   'phases',
#   'in',
#   'the',
#   'life',
#   'cycle',
#   'of',
#   'application',
#   'development',
#   'and',
#   'Bug',
#   'fixing',
#   '.'],
#  ['Implementation',
#   'of',
#   'the',
#   'application',
#   'on',
#   'Production',
#   'Server',
#   'Prepared',
#   'root',
#   'cause',
#   'analysis',
#   'for',
#   'problems',
#   'occurred',
#   'Preparation',
#   'of',
#   'LLA',
#   'Created',
#   'Procedures',
#   'Triggers',
#   'Functions',
#   'and',
#   'Packages',
#   '.'],
#  ['Coordinated',
#   'physical',
#   'changes',
#   'to',
#   'computer',
#   'data',
#   'bases',
#   'codes',
#   'tested',
#   'and',
#   'implemented',
#   'Oracle',
#   'and',
#   'SQL',
#   'data',
#   'base',
#   'applying',
#   'knowledge',
#   'of',
#   'data',
#   'base',
#   'management',
#   'system',
#   '.'],
#  ['Brief',
#   'description',
#   'of',
#   'the',
#   'project',
#   ':',
#   'DHL',
#   'is',
#   'internationally',
#   'renowned',
#   'logistics',
#   'provider',
#   'and',
#   'provide',
#   'Warehousing/Supply',
#   'Chain',
#   'solutions',
#   'through-out',
#   'the',
#   'world',
#   'with',
#   'key',
#   'focus',
#   'on',
#   'Europe',
#   '.'],
#  ['The',
#   'warehousing',
#   'solutions',
#   'are',
#   'built',
#   'around',
#   'specific',
#   'In-house',
#   'products',
#   'built',
#   'using',
#   'technologies',
#   'like',
#   'PowerBuilder',
#   'JAVA',
#   '.NET',
#   'and',
#   'are',
#   'used',
#   'extensively',
#   'by',
#   'key',
#   'customers',
#   'in',
#   'Europe',
#   'Asia',
#   'Pacific',
#   '.'],
#  ['HCL',
#   '’',
#   's',
#   'role',
#   'involves',
#   'in',
#   'maintenance',
#   'and',
#   'support',
#   'for',
#   'these',
#   'applications',
#   'and',
#   'provide',
#   'some',
#   'enhancements',
#   'to',
#   'these',
#   'products',
#   '.'],
#  ['Responsible',
#   'for',
#   ':',
#   'Requirements',
#   'Enhancements',
#   'and',
#   'customization',
#   'of',
#   'existing',
#   'software',
#   'in',
#   'all',
#   'phases',
#   'in',
#   'the',
#   'life',
#   'cycle',
#   'of',
#   'application',
#   'development',
#   'and',
#   'production',
#   'support',
#   '.'],
#  ['Involved',
#   'in',
#   'different',
#   'activities',
#   'like',
#   'incident',
#   'management',
#   'problem',
#   'management',
#   'and',
#   'change',
#   'management',
#   '.'],
#  ['Provided',
#   'support',
#   'to',
#   'all',
#   'application',
#   'development',
#   'in',
#   'the',
#   'areas',
#   'of',
#   'code',
#   'reviews',
#   'code',
#   'enhancements',
#   '.'],
#  ['Understand',
#   'the',
#   'functionality',
#   'of',
#   'the',
#   'application',
#   'by',
#   'going',
#   'through',
#   'functional',
#   'requirement',
#   'and',
#   'giving',
#   'suggestion',
#   'if',
#   'found',
#   'any',
#   'disturbances',
#   '.'],
#  ['Involved',
#   'in',
#   'the',
#   'CR',
#   '’',
#   's',
#   '(',
#   'Change',
# ...
#   'Life',
#   'Cycle',
#   '(',
#   'SDLC',
#   ')',
#   'including',
#   'requirements',
#   'analysis',
#   'design',
#   'development',
#   'testing',
#   'maintenance',
#   'and',
#   'enhancements',
#   'Sun',
#   'Certified',
#   'Java',
#   'Programmer',
#   '1.4',
#   'and',
#   'Sun',
#   'Certified',
#   'Web',
#   'Component',
#   'Developer',
#   '1.4',
#   'Yonkyu',
#   'Japanese',
#   'Proficiency',
#   'Level',
#   'Employment',
#   'Details',
#   'Education',
#   'Details',
#   'BCA',
#   'VIIT',
#   'College',
#   'Pune',
#   'YCMOU',
#   'University',
#   '.'],
#  ['Diploma',
#   'in',
#   'Production',
#   'Technology',
#   'SVCP',
#   'College',
#   'Pune',
#   'MSBTE',
#   '2000',
#   'Skill',
#   'Sets',
#   'Programming',
#   'Languages',
#   ':',
#   'JAVA',
#   'Web',
#   'Technologies',
#   ':',
#   'JSP',
#   'Servlet',
#   'JDBC',
#   'Hibernate',
#   'Spring',
#   'MVC',
#   'Struts2',
#   'AngularJS',
#   'Ajax',
#   'REST',
#   'API',
#   'Jquery',
#   'ANT',
#   'MAVEN',
#   'Database',
#   ':',
#   'Oracle',
#   'MySQL',
#   'Other',
#   'Tools',
#   ':',
#   'TOAD',
#   'Tomcat',
#   'JBOSS',
#   'RAD',
#   'Eclipse',
#   'Netbeans',
#   'Spring',
#   'Source',
#   'Tools',
#   'IDE',
#   'Project',
#   'Details',
#   'Dart',
#   'Tool',
#   'May',
#   '2016-',
#   'September',
#   '2016',
#   '(',
#   'Tech',
#   'Mahindra',
#   'Ltd',
#   'Pune',
#   ')',
#   'Client',
#   ':',
#   'AT',
#   '&',
#   'T',
#   'Project',
#   'Overview',
#   ':',
#   'This',
#   'tool',
#   'used',
#   'for',
#   'creating',
#   'request',
#   '.'],
#  ['Data', 'member', 'can', 'create', 'the', 'request', '.'],
#  ['Team', 'lead', 'can', 'review', 'and', 'approve', 'the', 'request', '.'],
#  ['There',
#   'are',
#   'validation',
#   'approval',
#   'process',
#   'Trigger',
#   'Reports',
#   'are',
#   'main',
#   'utility',
#   'used',
#   '.'],
#  ['Technologies',
#   'Used',
#   ':',
#   'Spring',
#   'MVC',
#   'JSP',
#   'Servlets',
#   'Oracle',
#   '10g',
#   'JavaScript',
#   'Tomcat',
#   'Apache',
#   'Ant',
#   'SVN',
#   'Roles',
#   'and',
#   'Responsibilities',
#   ':',
#   'Detail',
#   'understanding',
#   'of',
#   'functional',
#   'and',
#   'technical',
#   'requirements',
#   '.'],
#  ['Requirement',
#   'Gathering',
#   'and',
#   'Prototyping',
#   'of',
#   'the',
#   'application',
#   '.'],
#  ['Involvement', 'in', 'Coding', 'and', 'Change', 'Request', '.'],
#  ['Onshore',
#   '-',
#   'offshore',
#   'coordination',
#   'by',
#   'weekly',
#   'status',
#   'meeting',
#   '.'],
#  ['Reporting',
#   'to',
#   'onshore',
#   'and',
#   'offshore',
#   'leaderships',
#   'via',
#   'excel',
#   'and',
#   'emails',
#   '.'],
#  ['Docserver',
#   'November',
#   '2014',
#   '–',
#   'October',
#   '2015',
#   '(',
#   'Tech',
#   'Mahindra',
#   'Ltd',
#   'Pune',
#   ')',
#   'Client',
#   ':',
#   'AT',
#   '&',
#   'T',
#   'Project',
#   'Overview',
#   ':',
#   'Thisapplication',
#   'manages',
#   'different',
#   'types',
#   'of',
#   'documents',
#   'linked',
#   'with',
#   'several',
#   'tracks',
#   '.'],
#  ['This', 'is', 'a', 'single', 'page', 'web', 'application', '.'],
#  ['An',
#   'authorized',
#   'user',
#   'can',
#   'access',
#   'the',
#   'required',
#   'documents',
#   'after',
#   'logging',
#   'in',
#   'with',
#   'his',
#   'Attuid',
#   'and',
#   'password',
#   '.'],
#  ['Technologies',
#   'Used',
#   ':',
#   'AngularJs',
#   'Spring',
#   'REST',
#   'API',
#   'html',
#   'bootstrap',
#   'css',
#   'Mockito',
#   'Test',
#   'cases',
#   'Oracle',
#   '10g',
#   'Apache',
#   'Maven',
#   'SVN',
#   'Roles',
#   'and',
#   'Responsibilities',
#   ':',
#   'Detail',
#   'understanding',
#   'of',
#   'functional',
#   'and',
#   'technical',
#   'requirements',
#   '.'],
#  ['Requirement',
#   'Gathering',
#   'and',
#   'Prototyping',
#   'of',
#   'the',
#   'application',
#   '.'],
#  ['Involvement', 'in', 'Coding', 'and', 'Change', 'Request', '.'],
#  ['Onshore',
#   '-',
#   'offshore',
#   'coordination',
#   'by',
#   'weekly',
#   'status',
#   'meeting',
#   '.'],
#  ['Reporting',
#   'to',
#   'onshore',
#   'and',
#   'offshore',
#   'leaderships',
#   'via',
#   'excel',
#   'and',
#   'emails',
#   '.'],
#  ['RentPro',
#   'April',
#   '2012-',
#   'January',
#   '2013',
#   '(',
#   'Carpro',
#   'Systems',
#   'India',
#   'Pvt',
#   '.'],
#  ['Ltd.',
#   'Pune',
#   ')',
#   'Project',
#   'Overview',
#   ':',
#   'This',
#   'is',
#   'the',
#   'complete',
#   'software',
#   'solution',
#   'for',
#   'car',
#   'rental',
#   'companies',
#   'with',
#   'third',
#   'party',
#   'integration',
#   'with',
#   'Debitors',
#   'adjusters',
#   'branches',
#   'insurance',
#   'companies',
#   '.'],
#  ['Default', 'Control', 'to', 'maintain', 'branch', 'level', 'settings', '.'],
#  ['Allows',
#   'the',
#   'user',
#   'create',
#   'the',
#   'reservations',
#   'rentals',
#   'and',
#   'lease',
#   'through',
#   'online',
#   '.'],
#  ['Technologies',
#   'Used',
#   ':',
#   'Spring',
#   'Hibernate',
#   'JSP',
#   'Servlets',
#   'MSSQL',
#   'Server',
#   'Tomcat',
#   '.'],
#  ['SVN',
#   'Roles',
#   'and',
#   'Responsibilities',
#   ':',
#   'Detail',
#   'understanding',
#   'of',
#   'functional',
#   'and',
#   'technical',
#   'requirements',
#   '.'],
#  ['Responsible', 'for', 'developing', 'the', 'pages', '.'],
#  ['JIEM-Web',
#   'mock',
#   'August',
#   '2011-December',
#   '2011',
#   '(',
#   'Softbridge',
#   'Solutions',
#   'Pvt',
#   '.'],
#  ['Ltd.',
#   'Pune',
#   ')',
#   'Project',
#   'Overview',
#   ':',
#   'Webmockis',
#   'a',
#   'website',
#   'developed',
#   'for',
#   'JIEM',
#   'Japan',
#   '.'],
#  ['It', 'has', '3', 'main', 'modules', '.'],
#  ['Accounting', 'Ticketing', 'and', 'Group', 'Admin', '.'],
#  ['This', 'site', 'is', 'for', 'online', 'CET', 'exam', 'for', 'Japan', '.'],
#  ['From',
#   'this',
#   'site',
#   'you',
#   'can',
#   'register',
#   'and',
#   'purchase',
#   'online',
#   'ticket',
#   'for',
#   'exam',
#   'using',
#   'payment',
#   'gateway',
#   '.'],
#  ['Technologies',
#   'Used',
#   ':',
#   'Struts2',
#   'JSP',
#   'Hibernate3',
#   'Ajax',
#   'Jquery',
#   'Java',
#   'Script',
#   'MySQL',
#   '5.1',
#   'Eclipse',
#   'Tomcat',
#   'SVN',
#   'Roles',
#   'and',
#   'Responsibilities',
#   ':',
#   'Module',
#   'Lead',
#   'for',
#   'Ticketing',
#   'Module',
#   'Detail',
#   'understanding',
#   'of',
#   'functional',
#   'and',
#   'technical',
#   'requirements',
#   '.'],
#  ['Involvement',
#   'in',
#   'Coding',
#   'and',
#   'Change',
#   'Request',
#   'Viit',
#   'ERP',
#   'System',
#   'April',
#   '2009-August',
#   '2011',
#   '(',
#   'Visionindia',
#   'Software',
#   'Exports',
#   'Pvt',
#   '.'],
#  ['Ltd.',
#   'Pune',
#   ')',
#   'Client',
#   ':',
#   'Vishwakarma',
#   'Institute',
#   'of',
#   'Information',
#   'technology',
#   'Kondhwa',
#   'Bk',
#   '.'],
#  ['Pune',
#   'Project',
#   'Overview',
#   ':',
#   'This',
#   'is',
#   'an',
#   'Engineering',
#   'college',
#   'ERP',
#   'System',
#   'which',
#   'is',
#   'on',
#   'web',
#   'contains',
#   'eighteen',
#   'online',
#   'modules',
#   '.'],
#  ['Admission',
#   'Fees',
#   'Exam',
#   'Student',
#   'Attendance',
#   'Feedback',
#   'Infrastructure',
#   'Organization',
#   'Inward-Outward',
#   'Alumni',
#   'Hostel',
#   'and',
#   'Records',
#   'are',
#   'some',
#   'of',
#   'them',
#   '.'],
#  ['Online',
#   'admission',
#   'facility',
#   'is',
#   'provided',
#   'through',
#   'this',
#   'ERP',
#   '.'],
#  ['Technologies',
#   'Used',
#   ':',
#   'Jsp',
#   'Servlets',
#   'Hibernate',
#   'JavaScript',
#   'Jasper',
#   'Report',
#   'MySQL',
#   '5.1',
#   'NetBeans',
#   'Visual',
#   'Web',
#   'Pack',
#   'Jakarta',
#   'Tomcat',
#   '6.0.16',
#   'Roles',
#   'and',
#   'Responsibilities',
#   ':',
#   'Detail',
#   'understanding',
#   'of',
#   'functional',
#   'and',
#   'technical',
#   'requirements',
#   '.'],
#  ['Involvement', 'in', 'Coding', 'and', 'Change', 'Request', '.'],
#  ['Horizon',
#   'November',
#   '2007-',
#   'March',
#   '2008',
#   '(',
#   'HSBC',
#   'Global',
#   'Technology',
#   'Pune',
#   ')',
#   'Client',
#   ':',
#   'First',
#   'Direct',
#   'Bank',
#   'in',
#   'UK',
#   'Project',
#   'Overview',
#   ':',
#   'This',
#   'is',
#   'Web',
#   'Base',
#   'project',
#   'which',
#   'is',
#   'developed',
#   'for',
#   'First',
#   'Direct',
#   'Bank',
#   'in',
#   'UK',
#   '.'],
#  ['It',
#   'contains',
#   'various',
#   'account',
#   'functionalities',
#   'like',
#   'Sweep',
#   'Regular',
#   'Saver',
#   'account',
#   'etc',
#   '.'],
#  ['Technologies',
#   'Used',
#   ':',
#   'Rational',
#   'Software',
#   'Modeler',
#   'MKS',
#   'Mercury',
#   'Quality',
#   'Center',
#   'JDK',
#   '1.4',
#   'and',
#   'Web',
#   'Sphere',
#   'Portal',
#   'Server',
#   'RAD',
#   '7.0',
#   'Roles',
#   'and',
#   'Responsibilities',
#   ':',
#   'Design',
#   'Relational',
#   'Diagram',
#   'Using',
#   'RSM',
#   '(',
#   'Rational',
#   'Software',
#   'Modeler',
#   ')',
#   'Alliance',
#   'Business',
#   'School',
#   'March',
#   '2005-December',
#   '2006',
#   '(',
#   'Visionindia',
#   'Software',
#   'Exports',
#   'Pvt',
#   '.'],
#  ['Ltd.',
#   'Pune',
#   ')',
#   'Client',
#   ':',
#   'Bangalore',
#   'Distance',
#   'Learning',
#   'School',
#   'Project',
#   'Overview',
#   ':',
#   'This',
#   'is',
#   'a',
#   'Complete',
#   'Distance',
#   'Learning',
#   'Web',
#   'Site',
#   'of',
#   'Alliance',
#   'Business',
#   'Academy',
#   'Bangalore',
#   '.'],
#  ['This',
#   'provides',
#   'many',
#   'facilities',
#   'to',
#   'its',
#   'students',
#   'such',
#   'as',
#   'Student',
#   'Profile',
#   'Online',
#   'Assignments',
#   'Forum',
#   'Message',
#   'Board',
#   'Daily',
#   'Planner',
#   'Daily',
#   'Report',
#   'Profile',
#   'Settings',
#   'Etc',
#   '.'],
#  ['Technologies',
#   'Used',
#   ':',
#   'JSP',
#   'Jdbc',
#   'Java',
#   'Beans',
#   'Ajax',
#   'Hibernate',
#   'Oracle',
#   'Jakarta',
#   'Tomcat',
#   '5.5.9',
#   '.'],
#  ['Netbeans', 'JDK', '1.4', 'and', 'CVS', '.'],
#  ['Roles',
#   'and',
#   'Responsibilities',
#   ':',
#   'Detail',
#   'understanding',
#   'of',
#   'functional',
#   'and',
#   'technical',
#   'requirements',
#   '.'],
#  ['Involvement', 'in', 'Coding', 'and', 'Change', 'Request', '.'],
#  ['engineeringcampus.com',
#   'July',
#   '2001-',
#   'Jan',
#   '2004',
#   '(',
#   'Sunind',
#   'Systems',
#   'Pvt',
#   'Ltd.',
#   'Pune',
#   ')',
#   'Project',
#   'Overview',
#   ':',
#   'This',
#   'is',
#   'an',
#   'educational',
#   'portal',
#   'especially',
#   'developed',
#   'for',
#   'engineering',
#   'students',
#   '.'],
#  ['Engineeringcampus.com',
#   'is',
#   'all',
#   'about',
#   'sharing',
#   'the',
#   'expertise',
#   'of',
#   'various',
#   'subject',
#   'experts',
#   'spread',
#   'all',
#   'across',
#   'Maharashtra',
#   'and',
#   'various',
#   'places',
#   'with',
#   'every',
#   'engineering',
#   'student',
#   '.'],
#  ['Technologies',
#   'Used',
#   ':',
#   'HTML',
#   'Oracle',
#   'and',
#   'Jakarta',
#   'Tomcat',
#   '3.3',
#   'JDK',
#   '1.4',
#   '.'],
#  ['Roles',
#   'and',
#   'Responsibilities',
#   ':',
#   'Develop',
#   'static',
#   'Webpages',
#   'of',
#   'the',
#   'Engineering',
#   'study',
#   'material',
#   'and',
#   'question',
#   'papers',
#   '.'],
#  ['The',
#   'process',
#   'Involves',
#   'preparing',
#   'of',
#   'data',
#   'related',
#   'to',
#   'subjects',
#   'and',
#   'then',
#   'coding',
#   'for',
#   'developing',
#   'pages',
#   '.'],
#  ['Aparna',
#   'Pati',
#   'Mobile',
#   ':',
#   '+91',
#   '8143514380',
#   'Email',
#   ':',
#   'monika.appu384',
#   '@',
#   'gmail.com',
#   'SUMMARY',
#   'Almost',
#   '3',
#   'Years',
#   'of',
#   'professional',
#   'experience',
#   'in',
#   'the',
#   'Information',
#   'Technology',
#   'industry',
#   'with',
#   'proven',
#   'track',
#   'of',
#   'dot',
#   'net',
#   'development',
#   '.'],
#  ['Client-focused', 'I.T', '.'],
#  ['Software',
#   'engineer',
#   'with',
#   'expertise',
#   'in',
#   'all',
#   'phases',
#   'of',
#   'development',
#   'with',
#   'proven',
#   'success',
#   'in',
#   'delivering',
#   'large',
#   'scale',
#   'complex',
#   'projects',
#   'with',
#   'multiple',
#   'platforms',
#   'on',
#   'time',
#   'and',
#   'on',
#   'budget',
#   'leading',
#   'the',
#   'development',
#   'and',
#   'management',
#   'of',
#   'business',
#   'application',
#   'systems',
#   '.'],
#  ['Hands',
#   'on',
#   'experience',
#   'in',
#   'C',
#   '#',
#   '.Net',
#   'ASP.Net',
#   'MVC',
#   'Web',
#   'Services',
#   '.'],
#  ['Highly',
#   'interested',
#   'and',
#   'Strong',
#   'expertise',
#   'in',
#   'CSS',
#   'HTML5',
#   'XHTML/HTML',
#   'and',
#   'CSS3',
#   '.'],
#  ['Experienced',
#   'in',
#   'Architecting',
#   'and',
#   'developing',
#   'of',
#   'Web',
#   'Based',
#   'Applications',
#   '.'],
#  ['Knowledge',
#   'in',
#   'web',
#   'applications',
#   'using',
#   'ASP.Net',
#   'C',
#   '#',
#   'ADO.Net',
#   '.'],
#  ['Exposure',
#   'in',
#   'JavaScript',
#   'AJAX',
#   'CSS3',
#   'Jquery',
#   'and',
#   'Bootstrap',
#   '.'],
#  ['Good',
#   'understanding',
#   'on',
#   'multitier',
#   'architecture',
#   'application',
#   'development',
#   '.'],
#  ['Knowledge',
#   'in',
#   'MVC',
#   '-5',
#   'with',
#   'EDM',
#   '(',
#   'Entity',
#   'Data',
#   'Model',
#   ')',
#   '.'],
#  ['Good',
#   'technical',
#   'knowledge',
#   'and',
#   'excellent',
#   'Troubleshooting',
#   'skills',
#   'with',
#   'the',
#   'ability',
#   'to',
#   'understand',
#   'the',
#   'Business',
#   'Requirements',
#   '.'],
#  ['Dedicated',
#   'team',
#   'player',
#   'with',
#   'strong',
#   'focus',
#   'on',
#   'achieving',
#   'collective',
#   'goals',
#   'and',
#   'meeting',
#   'deadlines',
#   '.'],
#  ['Excellent',
#   'learning',
#   'skills',
#   'and',
#   'adapting',
#   'quickly',
#   'to',
#   'rapidly',
#   'changing/new',
#   'technologies',
#   'and',
#   'ready',
#   'to',
#   'take',
#   'the',
#   'challenges',
#   'with',
#   'a',
#   'Positive',
#   'attitude',
#   'and',
#   'dedication',
#   'towards',
#   'the',
#   'task/work',
#   'in',
#   'hand',
#   '.'],
#  ['ACHIEVEMENTS',
#   'Awarded',
#   'Regular',
#   'Employee',
#   'of',
#   'the',
#   'year',
#   'in',
#   '2015',
#   '.'],
#  ['Well-versed',
#   'communicator',
#   'and',
#   'liaison',
#   'to',
#   'all',
#   'levels',
#   'of',
#   'the',
#   'organization',
#   'from',
#   'developers',
#   'business',
#   'unit',
#   'systems',
#   'analysts',
#   'clients',
#   'and',
#   'executive',
#   'management',
#   '.'],
#  ['Successfully',
#   'implements',
#   'Application',
#   'Development',
#   'and',
#   'Infrastructure',
#   'projects',
#   'on',
#   'time',
#   'and',
#   'on',
#   'budget',
#   '.'],
#  ['TECHNICAL',
#   'SKILLS',
#   'Languages',
#   ':',
#   'MVC',
#   'C',
#   '#',
#   'ASP.Net',
#   'SQL',
#   'LINQ',
#   'HTTP',
#   'Services',
#   ':',
#   'Web',
#   'API',
#   'Web',
#   'Services',
#   'Microservices',
#   'Databases',
#   ':',
#   'SQL',
#   'Server',
#   'MS',
#   'Access',
#   '.'],
#  ['Scripting',
#   'Languages',
#   ':',
#   'JavaScript',
#   'Jquery',
#   'Ajax',
#   'CSS3',
#   'Bootstrap',
#   'Repositories',
#   ':',
#   'Git',
#   'Hub',
#   'TFS',
#   'Bit',
#   'Bucket',
#   '(',
#   'Tortoise',
#   'Hg',
#   ')',
#   'EDUCATIONAL',
#   'QUALIFICATION',
#   'Graduation',
#   'B.Tech',
#   'in',
#   'ECE',
#   '(',
#   'JNTU',
#   ')',
#   'from',
#   'Mallareddy',
#   'College',
#   'of',
#   'Engineering',
#   '2014',
#   'PROFESSIONAL',
#   'EXPERIENCE',
#   'Ascendia',
#   'Technologies',
#   'Pvt',
#   'Ltd',
#   '/',
#   'Kaara',
#   'Technologies',
#   'Pvt',
#   'Ltd',
#   '(',
#   'www.kaaratech.in',
#   ')',
#   '(',
#   '06/15',
#   '–',
#   'Till',
#   'Date',
#   ')',
#   'Kaara',
#   'is',
#   'a',
#   'people',
#   'centric',
#   'organization',
#   'which',
#   'offers',
#   'Products',
#   'Processes',
#   'Services',
#   'Machines',
#   'Success',
#   'and',
#   'Growth',
#   'to',
#   'people',
#   '.'],
#  ['It',
#   '’',
#   's',
#   'expertise',
#   'in',
#   'Product',
#   'Development',
#   'Mobile',
#   'Application',
#   'Data',
#   'Analytics',
#   'Artificial',
#   'Intelligence',
#   'Machine',
#   'Learning',
#   'gives',
#   'a',
#   'best',
#   'scope',
#   'for',
#   'businesses',
#   'and',
#   'customers',
#   'for',
#   'every',
#   'solution',
#   'they',
#   'strive',
#   'for',
#   '.'],
#  ['Human',
#   'Resource',
#   'Management',
#   'System',
#   ':',
#   '(',
#   'Dec/15',
#   '–',
#   'Till',
#   'Date',
#   ')',
#   'Client',
#   ':',
#   'Canopy',
#   'Workforce',
#   'Solutions',
#   'Environment',
#   ':',
#   'Asp.net',
#   'C',
#   '#',
#   'Web',
#   'API',
#   'Web',
#   'Services',
#   'Jquery',
#   'SQL',
#   'This',
#   'project',
#   'is',
#   'initiated',
#   'to',
#   're-architecture',
#   'the',
#   'current',
#   'HR',
#   'management',
#   'system',
#   '.'],
#  ['It',
#   'allows',
#   'the',
#   'communication',
#   'using',
#   'web',
#   'services',
#   'and',
#   'providing',
#   'new',
#   'staging',
#   'and',
#   'development',
#   'environments',
#   'along',
#   'with',
#   'offering',
#   'virtualization',
#   'of',
#   'web',
#   'servers',
#   'and',
#   'clustering',
#   'of',
#   'SQL',
#   'database',
#   'servers',
#   'to',
#   'allow',
#   'for',
#   'failover',
#   'in',
#   'the',
#   'event',
#   'of',
#   'a',
#   'hardware',
#   'malfunction',
#   '.'],
#  ['HR',
#   'Management',
#   'system',
#   'offers',
#   'saving',
#   'and',
#   'managing',
#   'employee',
#   'data',
#   'efficiently',
#   '.'],
#  ['It',
#   'provides',
#   'various',
#   'features',
#   'for',
#   'giving',
#   'an',
#   'organization',
#   'more',
#   'tremendous',
#   'performance',
#   'PowWowHR',
#   'is',
#   'the',
#   'only',
#   'HR',
#   'system',
#   'that',
#   'combines',
#   'all',
#   'of',
#   'the',
#   'foundational',
#   'features',
#   'to',
#   'track',
#   'and',
#   'manage',
#   'employee',
#   'data',
#   'and',
#   'compliance',
#   'issues',
#   'while',
#   'engaging',
#   'your',
#   'employees',
#   'with',
#   'social',
#   'business',
#   'tools',
#   'to',
#   'work',
#   'smarter',
#   '.'],
#  ...]

# %% [markdown]
# #### 3) Building Fasttext Model using Gensim Library

# %%
modelFT = FastText(data, size=100, window=5, min_count=5, workers=4,sg=1)
modelFT

# %%
# evaluating the most similar words to 'java' using Fasttext model...
modelFT.most_similar('java')
# Out:
# [('JSPs', 0.9023535251617432),
#  ('J2EE/Java', 0.9003547430038452),
#  ('servlet', 0.8958097696304321),
#  ('JSP', 0.8879826068878174),
#  ('JSF', 0.8825526237487793),
#  ('Java/J2ee', 0.8789649605751038),
#  ('front-end', 0.8755855560302734),
#  ('Java/J2EE', 0.8739306330680847),
#  ('JSTL', 0.8704612255096436),
#  ('CoreJava', 0.8688318729400635)]

# %%
# evaluating the most similar words to 'python' using Fasttext model...
modelFT.most_similar('python')
# Out:
# [('Python', 0.9732093214988708),
#  ('JSon', 0.9431465268135071),
#  ('hub', 0.9393289685249329),
#  ('XSL', 0.9371820688247681),
#  ('GitHub', 0.9356774091720581),
#  ('Bitbucket', 0.9342490434646606),
#  ('MAVEN', 0.9332001209259033),
#  ('CXF', 0.9326076507568359),
#  ('Json', 0.9325049519538879),
#  ('Knockout', 0.9320213794708252)]

# %% [markdown]
# #### 4) Building Word2Vec Model Using Gensim

# %%
from gensim.models import Word2Vec
modelWV = Word2Vec(data, min_count=1)
print(modelWV)
# Out:
# Word2Vec(vocab=31662, size=100, alpha=0.025)

# %%
# evaluating the most similar words to 'java' using word2vec model...
modelWV.most_similar('java')
# Out:
# [('spring', 0.9844119548797607),
#  ('servlet', 0.9804044961929321),
#  ('JSTL', 0.9750860333442688),
#  ('framework', 0.9721617698669434),
#  ('JSP', 0.971493124961853),
#  ('Restful', 0.9673343300819397),
#  ('Spring', 0.9652677178382874),
#  ('persistence', 0.9639869928359985),
#  ('API', 0.963525652885437),
#  ('JUnit', 0.9631530046463013)]

# %%
# evaluating the most similar words to 'python' using word2vec model...
modelWV.most_similar('python')
# Out:
# [('Perl', 0.9912320375442505),
#  ('JSR', 0.991031289100647),
#  ('RESTFUL', 0.9910008311271667),
#  ('Redux', 0.9896095991134644),
#  ('Storm', 0.988836407661438),
#  ('Pentaho', 0.9886062741279602),
#  ('Highcharts', 0.9885555505752563),
#  ('MapReduce', 0.9882293939590454),
#  ('HBase', 0.9881883263587952),
#  ('D3', 0.9880128502845764)]

# %% [markdown]
# ### ---End Of Explanation---
